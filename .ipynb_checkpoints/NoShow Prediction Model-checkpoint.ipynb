# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(font_scale=1.5)
import numpy as np
import datetime
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
#Open CSV File
df = pd.read_csv(r'C:\Users\carlb\Desktop\Appointments.csv')

# %%
#Remove blank hh:mm:ss:ms from fldDate
df['fldDate'] = pd.to_datetime(df['fldDate'],errors="coerce").dt.strftime("%Y-%m-%d")

# %%
#Convert dfTime from standard time to military w/ms
df['fldTime'] = pd.to_datetime(df['fldTime'],errors="coerce").dt.strftime("%H:%M:%S.%f")

# %%
#Combine fldDate and fldTime into df.combined
df['combined'] = df['fldDate'] + ' ' + df['fldTime']

# %%
#make df['combined'] and df['fldLastUpdatedDate'] the same dtype
df['combined'] = pd.to_datetime(df['combined'])
df['fldLastUpdatedDate']= pd.to_datetime(df['fldLastUpdatedDate'])
df['fldScheduleCreatedDt'] = pd.to_datetime(df['fldScheduleCreatedDt'])

# %%
df.dtypes
# Out:
# fldScheduleId                              int64
# fldClientId                                int64
# fldCaseId                                float64
# fldHearAboutUs                             int64
# fldContactMode                             int64
# fldCrisisLevelId                           int64
# fldAppointmentNotes                       object
# fldReferalTypeId                           int64
# fldSchedule                              float64
# fldLocation                                int64
# fldStaffId                                object
# fldDate                                   object
# fldTime                                   object
# fldDuration                               object
# fldOnCallYesNo                           float64
# fldServiceId                             float64
# fldApptOutcomeId                           int64
# fldProgramListId                          object
# fldClientVisitedYesNoCancelled           float64
# ...

# %%
#insert df['combined'] values into df['fldLastUpdatedDate']null() cells

# %%
#figure out how the rest of the shit below fits

# %%
#Calculate time between schedule timestamp and actual appt time
df['timefromscheduled'] = df['fldLastUpdatedDate'] - df['fldScheduleCreatedDt']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Python\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# D:\Python\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# D:\Python\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
#might not be necessary now
#convert df.timefromscheduled to float
df.timefromscheduled = df['timefromscheduled'] / np.timedelta64(1, 's') / 86400

# %%
#set plt axis
x = [df.index[df.timefromscheduled.notnull()]]
y = [df.timefromscheduled[df.index[df.timefromscheduled.notnull()]]]

# %%
plt.scatter(x,y)

# %%
#Save df to csv
df.to_csv(r'C:\Users\carlb\Desktop\Appointments_pred_2.csv')
